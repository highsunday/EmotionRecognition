# %%
import os
import numpy as np
from tqdm import tqdm
from glob import glob
from PIL import Image
import math
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
img_size=48

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_path='images/fer2013/train'
val_path='images/fer2013/valid'

Train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode="nearest",
    horizontal_flip=True,
) 

Test_datagen = ImageDataGenerator(
    rescale=1./255
)

# %%
Train_generator=Train_datagen.flow_from_directory(train_path,target_size=(img_size,img_size),batch_size=64,class_mode='categorical')
# Out:
# Found 28715 images belonging to 7 classes.

# %%
Val_generator=Test_datagen.flow_from_directory(val_path,target_size=(img_size,img_size),batch_size=64,class_mode='categorical')
# Out:
# Found 3589 images belonging to 7 classes.

# %%
# test Train_datagen performance
from tensorflow.keras.preprocessing import image # 影象預處理模組

train_path_soft='images/fer2013/train/Angry'

fnames = [os.path.join(train_path_soft, fname) for fname in os.listdir(train_path_soft)]
img_path = fnames[3] # 選擇一張圖片進行增強
img = image.load_img(img_path, target_size=(150, 150)) # 讀取影象並調整大小
x = image.img_to_array(img) # 形狀轉換為(150,150,3)的Numpy陣列
x = x.reshape((1,) + x.shape)

i = 0
# 生成隨機變換後圖像批量，迴圈是無限生成，也需要我們手動指定終止條件
for batch in Train_datagen.flow(x, batch_size=1):
    plt.figure(i)
    imgplot = plt.imshow(image.array_to_img(batch[0]))
    i += 1
    if i % 10 == 0:
        break
plt.show()

# %%
from tensorflow.keras import layers
from tensorflow.keras import models

model=models.Sequential()
model.add(layers.Conv2D(64,(7,7),strides=1,padding='same',activation='relu',input_shape=(img_size,img_size,3),kernel_initializer='he_normal'))
#model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(128,(3,3),padding='same',activation='relu',kernel_initializer='he_normal'))
model.add(layers.Conv2D(128,(3,3),padding='same',activation='relu',kernel_initializer='he_normal'))
#model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(256,(3,3),padding='same',activation='relu',kernel_initializer='he_normal'))
model.add(layers.Conv2D(256,(3,3),padding='same',activation='relu',kernel_initializer='he_normal'))
#model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(512,(3,3),padding='same',activation='relu',kernel_initializer='he_normal'))
model.add(layers.Conv2D(512,(3,3),padding='same',activation='relu',kernel_initializer='he_normal'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Conv2D(1024,(3,3),padding='same',activation='relu',kernel_initializer='he_normal'))
model.add(layers.Conv2D(1024,(3,3),padding='same',activation='relu',kernel_initializer='he_normal'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Flatten())
model.add(layers.Dense(240,activation='relu',kernel_initializer='he_normal'))
model.add(layers.BatchNormalization())
model.add(layers.Dense(7,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 64)        9472
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 256)       295168
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 12, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 512)         1180160
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 512)         2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 3, 3, 1024)        4719616
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 3, 3, 1024)        9438208
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 1024)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               524800
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 3591
# =================================================================
# Total params: 19,344,391
# Trainable params: 19,343,367
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
import tensorflow as tf

# %%
model.compile(optimizer=tf.keras.optimizers.Nadam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import TensorBoard

# %%
root_logdir = os.path.join(os.curdir, "my_logs")
def get_run_logdir():
    import time
    run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)

run_logdir = get_run_logdir()
run_logdir
# Out:
# './my_logs/run_2020_12_03-20_47_23'

# %%
modelName=run_logdir[10:]+".h5"

# %%
checkpoint_cb=ModelCheckpoint(modelName, save_best_only=True)

# %%
early_stopping_cb = EarlyStopping(patience=10,restore_best_weights=True)

# %%
tensorboard_cb = TensorBoard(run_logdir)

# %%
history=model.fit_generator(
    Train_generator,
    steps_per_epoch=len(Train_generator),
    #steps_per_epoch=15779//batch_size+1,
    epochs=500,
    validation_data=Val_generator,
    validation_steps=len(Val_generator),
    #callbacks=[checkpoint_cb, early_stopping_cb,tensorboard_cb]
    callbacks=[checkpoint_cb, early_stopping_cb,tensorboard_cb]
)
# Out:
# WARNING:tensorflow:From <ipython-input-18-fc52af42ade7>:9: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/500
#   1/449 [..............................] - ETA: 0s - loss: 2.1083 - accuracy: 0.1562WARNING:tensorflow:From /home/highsunday/anaconda3/envs/python_yolo/lib/python3.7/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#   2/449 [..............................] - ETA: 15s - loss: 2.1166 - accuracy: 0.1875WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0161s vs `on_train_batch_end` time: 0.0530s). Check your callbacks.
# 449/449 [==============================] - 39s 87ms/step - loss: 1.8151 - accuracy: 0.2412 - val_loss: 2.9062 - val_accuracy: 0.1206
# Epoch 2/500
# 449/449 [==============================] - 23s 51ms/step - loss: 1.8001 - accuracy: 0.2437 - val_loss: 2.5934 - val_accuracy: 0.1845
# Epoch 3/500
# 449/449 [==============================] - 23s 51ms/step - loss: 1.7948 - accuracy: 0.2527 - val_loss: 2.4868 - val_accuracy: 0.1931
# Epoch 4/500
# 449/449 [==============================] - 23s 51ms/step - loss: 1.7873 - accuracy: 0.2585 - val_loss: 1.7760 - val_accuracy: 0.2458
# Epoch 5/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.7849 - accuracy: 0.2589 - val_loss: 1.8158 - val_accuracy: 0.2463
# Epoch 6/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.7829 - accuracy: 0.2615 - val_loss: 1.7862 - val_accuracy: 0.2555
# Epoch 7/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.7706 - accuracy: 0.2670 - val_loss: 1.8224 - val_accuracy: 0.1970
# Epoch 8/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.7426 - accuracy: 0.2827 - val_loss: 1.8562 - val_accuracy: 0.2653
# Epoch 9/500
# 449/449 [==============================] - 23s 51ms/step - loss: 1.6990 - accuracy: 0.3144 - val_loss: 1.6535 - val_accuracy: 0.3500
# Epoch 10/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.6318 - accuracy: 0.3528 - val_loss: 1.7198 - val_accuracy: 0.3717
# Epoch 11/500
# 449/449 [==============================] - 23s 51ms/step - loss: 1.5805 - accuracy: 0.3800 - val_loss: 1.5708 - val_accuracy: 0.3617
# Epoch 12/500
# 449/449 [==============================] - 23s 51ms/step - loss: 1.5306 - accuracy: 0.4083 - val_loss: 1.5118 - val_accuracy: 0.4600
# Epoch 13/500
# 449/449 [==============================] - 23s 51ms/step - loss: 1.4771 - accuracy: 0.4305 - val_loss: 1.4112 - val_accuracy: 0.4809
# Epoch 14/500
# 449/449 [==============================] - 23s 52ms/step - loss: 1.4904 - accuracy: 0.4197 - val_loss: 1.4035 - val_accuracy: 0.4441
# Epoch 15/500
# 449/449 [==============================] - 23s 52ms/step - loss: 1.4008 - accuracy: 0.4646 - val_loss: 1.3899 - val_accuracy: 0.4868
# Epoch 16/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.3683 - accuracy: 0.4786 - val_loss: 1.8210 - val_accuracy: 0.4037
# Epoch 17/500
# 449/449 [==============================] - 23s 51ms/step - loss: 1.3336 - accuracy: 0.4890 - val_loss: 1.2842 - val_accuracy: 0.5183
# Epoch 18/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.3088 - accuracy: 0.4991 - val_loss: 4.9508 - val_accuracy: 0.5205
# Epoch 19/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.2737 - accuracy: 0.5161 - val_loss: 10.9168 - val_accuracy: 0.0159
# Epoch 20/500
# 449/449 [==============================] - 23s 51ms/step - loss: 1.2569 - accuracy: 0.5209 - val_loss: 1.2745 - val_accuracy: 0.5595
# Epoch 21/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.2410 - accuracy: 0.5298 - val_loss: 10.8376 - val_accuracy: 0.5024
# Epoch 22/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.2225 - accuracy: 0.5394 - val_loss: 2.2569 - val_accuracy: 0.5606
# Epoch 23/500
# 449/449 [==============================] - 23s 51ms/step - loss: 1.2087 - accuracy: 0.5411 - val_loss: 1.1710 - val_accuracy: 0.5536
# Epoch 24/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.1893 - accuracy: 0.5515 - val_loss: 2.3613 - val_accuracy: 0.5626
# Epoch 25/500
# 449/449 [==============================] - 23s 51ms/step - loss: 1.1735 - accuracy: 0.5560 - val_loss: 1.1125 - val_accuracy: 0.5885
# Epoch 26/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.1672 - accuracy: 0.5589 - val_loss: 1.1205 - val_accuracy: 0.5793
# Epoch 27/500
# 449/449 [==============================] - 23s 51ms/step - loss: 1.1533 - accuracy: 0.5650 - val_loss: 1.1017 - val_accuracy: 0.5913
# Epoch 28/500
# 449/449 [==============================] - 23s 51ms/step - loss: 1.1452 - accuracy: 0.5690 - val_loss: 1.0732 - val_accuracy: 0.5979
# Epoch 29/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.1435 - accuracy: 0.5699 - val_loss: 10.0822 - val_accuracy: 0.5887
# Epoch 30/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.1207 - accuracy: 0.5766 - val_loss: 2.4746 - val_accuracy: 0.6135
# Epoch 31/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.1166 - accuracy: 0.5779 - val_loss: 1.1068 - val_accuracy: 0.5748
# Epoch 32/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.1086 - accuracy: 0.5844 - val_loss: 40.8345 - val_accuracy: 0.6188
# Epoch 33/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.0948 - accuracy: 0.5883 - val_loss: 3.0400 - val_accuracy: 0.6060
# Epoch 34/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.0872 - accuracy: 0.5869 - val_loss: 1.3197 - val_accuracy: 0.5985
# Epoch 35/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.0818 - accuracy: 0.5910 - val_loss: 2.3075 - val_accuracy: 0.6010
# Epoch 36/500
# 449/449 [==============================] - 23s 51ms/step - loss: 1.0723 - accuracy: 0.6010 - val_loss: 1.0448 - val_accuracy: 0.6099
# Epoch 37/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.0667 - accuracy: 0.5964 - val_loss: 1.0820 - val_accuracy: 0.5952
# Epoch 38/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.0575 - accuracy: 0.6012 - val_loss: 1.2482 - val_accuracy: 0.6057
# Epoch 39/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.0578 - accuracy: 0.6052 - val_loss: 2.5036 - val_accuracy: 0.6052
# Epoch 40/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.0472 - accuracy: 0.6069 - val_loss: 1.4038 - val_accuracy: 0.6074
# Epoch 41/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.0373 - accuracy: 0.6098 - val_loss: 1.6026 - val_accuracy: 0.6099
# Epoch 42/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.0324 - accuracy: 0.6118 - val_loss: 1.0864 - val_accuracy: 0.6085
# Epoch 43/500
# 449/449 [==============================] - 23s 51ms/step - loss: 1.0325 - accuracy: 0.6117 - val_loss: 1.0029 - val_accuracy: 0.6205
# Epoch 44/500
# 449/449 [==============================] - 20s 46ms/step - loss: 1.0240 - accuracy: 0.6160 - val_loss: 1.3335 - val_accuracy: 0.6319
# Epoch 45/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.0128 - accuracy: 0.6170 - val_loss: 1.0502 - val_accuracy: 0.6278
# Epoch 46/500
# 449/449 [==============================] - 20s 46ms/step - loss: 1.0125 - accuracy: 0.6203 - val_loss: 1.0039 - val_accuracy: 0.6272
# Epoch 47/500
# 449/449 [==============================] - 21s 46ms/step - loss: 1.0020 - accuracy: 0.6219 - val_loss: 1.1987 - val_accuracy: 0.6389
# Epoch 48/500
# 449/449 [==============================] - 21s 46ms/step - loss: 0.9925 - accuracy: 0.6262 - val_loss: 1.0119 - val_accuracy: 0.6319
# Epoch 49/500
# 449/449 [==============================] - 20s 46ms/step - loss: 0.9866 - accuracy: 0.6312 - val_loss: 1.0263 - val_accuracy: 0.6406
# Epoch 50/500
# 449/449 [==============================] - 20s 46ms/step - loss: 0.9866 - accuracy: 0.6279 - val_loss: 1.0094 - val_accuracy: 0.6356
# Epoch 51/500
# 449/449 [==============================] - 20s 46ms/step - loss: 0.9788 - accuracy: 0.6334 - val_loss: 1.0319 - val_accuracy: 0.6367
# Epoch 52/500
# 449/449 [==============================] - 21s 46ms/step - loss: 0.9723 - accuracy: 0.6337 - val_loss: 7.7649 - val_accuracy: 0.6434
# Epoch 53/500
# 449/449 [==============================] - 21s 46ms/step - loss: 0.9714 - accuracy: 0.6344 - val_loss: 10.0583 - val_accuracy: 0.5561
